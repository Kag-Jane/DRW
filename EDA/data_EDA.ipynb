# %% [markdown]
# #### Data EDA
#
# More examples with different feature engineering approaches can be found in [this notebook](https://www.kaggle.com/code/ahsuna123/anonymized-features-importance-selection-eda#1.-EXPLORATORY-DATA-ANALYSIS).

# %% [markdown]
# ##### Some feature engineering results from discussions
#
# https://www.kaggle.com/code/uzdavinys/drw-cypto-time-series-cross-validation-examples
#
# selected_features = [
#     "X863", "X856", "X344", "X598", "X862", "X385", "X852", "X603", "X860", "X674",
#     "X415", "X345", "X137", "X855", "X174", "X302", "X178", "X532", "X168", "X612",
#     "bid_qty", "ask_qty", "buy_qty", "sell_qty", "volume"
# ]
#
#
# https://www.kaggle.com/code/sadettinamilverdil/yat-r-m-tavsiyesi-de-ildir
#
# selection based on SHAP values
#
# selected_features = [
#     "X863", "X856", "X344", "X598", "X862", "X385", "X852", "X603", "X860", "X674",
#     "X415", "X345", "X137", "X855", "X174", "X302", "X178", "X532", "X168", "X612",
#     "X888","X421","X333",
#     "bid_qty", "ask_qty", "buy_qty", "sell_qty", "volume"
# ]
#
#
# https://www.kaggle.com/code/ahsuna123/anonymized-features-importance-selection-eda#1.-EXPLORATORY-DATA-ANALYSIS
#
# Top 20 features most correlated with target:
#
# selected_features = [
#     X21,X20,X28,X863,X29,
#     X19,X27,X22,X858,X219,
#     X860,X531,X287,X289,X291,
#     X293,X857,X295,X598,X218,
# ]

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from autogluon.tabular import TabularPredictor

import plotly.express as px

# %%
data_path = "/home/yang/team_kaggle/drw/data"

# %%
data = pd.read_parquet(Path(data_path, "train.parquet"))
